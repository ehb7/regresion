# %% [markdown]
# <a href="https://colab.research.google.com/github/ehb7/regresion/blob/main/Reg_multi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Datos
import numpy as np
import pandas as pd

# Visualizacion
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from random import random

# ML
from sklearn.linear_model import LinearRegression, Ridge, SGDRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn import metrics
import xgboost as xgb

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/House_Pricing_basic_dataset.csv')
df.describe()
# Out:
#               PRECIO         AREA  ...  INGRESOS_ZONA  POBLACION_ZONA
# count    5000.000000  5000.000000  ...    5000.000000     5000.000000
# mean   369621.797640   242.534648  ...   68583.108950    36163.516088
# std    105935.287688    30.175065  ...   10657.991228     9925.650059
# min      4781.700000   129.990000  ...   17796.630000      172.610000
# 25%    299273.175000   221.877500  ...   61480.565000    29403.930000
# 50%    369800.700000   242.990000  ...   68804.285000    36199.405000
# 75%    441363.000000   262.877500  ...   75783.342500    42861.290000
# max    740719.800000   355.690000  ...  107701.750000    69621.710000
#
# [8 rows x 7 columns]

# %%
target = ['PRECIO']
features = ['AREA','ANTIGUEDAD','HABITACIONES','DORMITORIOS','INGRESOS_ZONA','POBLACION_ZONA']

# %%
sns.displot(df['PRECIO'])
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)

# %%
X = df[features]
y = df[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  
X_test = scaler.transform(X_test)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(X_test)

# %%
plt.scatter(y_test,y_pred)
plt.plot(y_test,y_test,'r')
plt.title('True vs Predicted')
plt.xlabel('True values')
plt.ylabel('Predicted values')
plt.show()

# %%
error = y_pred - y_test.values
sns.displot(error)
plt.show()
